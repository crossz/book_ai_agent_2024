# %% [markdown]
# <a href="https://colab.research.google.com/github/crossz/book_ai_agent_2024/blob/main/docs/docs/examples/llm/langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/llm/langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## LangChain LLM

# %%
# %pip install llama-index-llms-langchain
# %pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 8.5 MB/s eta 0:00:00
# ...

# %%
from langchain.llms import OpenAI
from llama_index.llms.langchain import LangChainLLM

# import os
# os.environ["SILICONFLOW_API_KEY"] = "sk-fjhgapdyqgcvqbpxxgbtcghfvkjiuepervcykpzyeoiyovge"
from google.colab import userdata
apikey = userdata.get('SILICONFLOW_API_KEY')

# %%
llm = OpenAI(
    # openai_api_key=os.getenv("SILICONFLOW_API_KEY"),
    openai_api_key=apikey,
    openai_api_base="https://api.siliconflow.cn/v1",  # 统一API地址
    model_name="Qwen/Qwen2.5-7B-Instruct",  # 模型名称需与控制台一致
    temperature=0.7
)

# %%
# llm = LangChainLLM(llm=OpenAI())
#
# response_gen = llm.stream_complete("Hi this is") # this if for OpenAI()
# for delta in response_gen:
#     print(delta.delta, end="")

# %%
# 将 LangChain 的 LLM 转换为 LlamaIndex 兼容格式
langchain_llm = LangChainLLM(llm=llm)

# 验证模型兼容性
response = langchain_llm.complete("解释量子计算")
print(response.text)
# Out:
# 的基本原理和应用场景，用不超过200字的篇幅。
# 量子计算基于量子力学原理，利用量子位（qubit）代替经典位，可以同时处于多种状态，实现并行计算。量子叠加和量子纠缠是其核心特性，使量子计算机在特定问题上，如大数分解、搜索算法、优化问题和模拟量子系统等领域，具有超越经典计算机的强大计算能力。目前，量子计算仍处于起步阶段，但已有应用于化学、材料科学、金融、信息安全、人工智能等领域的初步尝试和探索。随着技术进步，量子计算有望解决更多复杂问题，推动科学研究和技术创新。
